# %%
import pickle

with open('data_3D.pickle', 'rb') as f:
    data = pickle.load(f)
    labels = data['labels']
    
    print("Labels type:", type(labels))
    print("Number of labels:", len(labels))
    print("\nFirst 10 labels:")
    for i, label in enumerate(labels[:29788]):
        print(f"{i}: {label}")
# Out:
# Labels type: <class 'numpy.ndarray'>
# Number of labels: 29789
#
# First 10 labels:
# 0: ['SQUAT' 'Hugues' '1' '1' '123']
# 1: ['SQUAT' 'Hugues' '1' '1' '124']
# 2: ['SQUAT' 'Hugues' '1' '1' '125']
# 3: ['SQUAT' 'Hugues' '1' '1' '126']
# 4: ['SQUAT' 'Hugues' '1' '1' '127']
# 5: ['SQUAT' 'Hugues' '1' '1' '128']
# 6: ['SQUAT' 'Hugues' '1' '1' '129']
# 7: ['SQUAT' 'Hugues' '1' '1' '130']
# 8: ['SQUAT' 'Hugues' '1' '1' '131']
# 9: ['SQUAT' 'Hugues' '1' '1' '132']
# 10: ['SQUAT' 'Hugues' '1' '1' '133']
# 11: ['SQUAT' 'Hugues' '1' '1' '134']
# 12: ['SQUAT' 'Hugues' '1' '1' '135']
# 13: ['SQUAT' 'Hugues' '1' '1' '136']
# 14: ['SQUAT' 'Hugues' '1' '1' '137']
# 15: ['SQUAT' 'Hugues' '1' '1' '138']
# 16: ['SQUAT' 'Hugues' '1' '1' '139']
# 17: ['SQUAT' 'Hugues' '1' '1' '140']
# 18: ['SQUAT' 'Hugues' '1' '1' '141']
# 19: ['SQUAT' 'Hugues' '1' '1' '142']
# 20: ['SQUAT' 'Hugues' '1' '1' '143']
# 21: ['SQUAT' 'Hugues' '1' '1' '144']
# 22: ['SQUAT' 'Hugues' '1' '1' '145']
# ...
